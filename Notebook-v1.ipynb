# %%
import time
time.sleep(0.1)  # Ensure the import is delayed to simulate a longer startup time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project_code
# Out:
# /content/drive/MyDrive/Project_code

# %%
# !pip install pip --upgrade pip
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.1/343.1 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 3.4 MB/s eta 0:00:00
# ...

# %%
# model=['mlp', 'cnn', 'lstm', 'transformer','rf', 'xgb', 'ada', 'cat', 'svm','lreg', prot_bert', 'esm2_t6_8m']

# features=['aac', 'dpc', 'tpc', 'pssm', 'physicochem', 'binary']

# loss=['bce', 'mse', 'mae', 'focal']
# pos_weight
# optim=['adam', 'sgd', 'rmsprop', 'adamw', 'amsgrad]
# sched=['step', 'exp', 'plateau', 'cosine']
# Sampling=['', 'under', 'smote', 'smotee', 'none']
# freeze_pretrained
# cv cross-validation(k-fold)
# plots= ['distribution', 'confusion', 'roc', 'pr']
#--dropout
over

# %%
# !python -u main.py \
  --model xgb \
  --fasta "/content/drive/MyDrive/Project_code/Triticum aestivum Plant1/Protein Sequences Triticum aestive  40% CD-Hit.fasta" \
  --excel "/content/drive/MyDrive/Project_code/Triticum aestivum Plant1/Triticum aestive -UB-Sites.xlsx" \
  --fasta2 "/content/drive/MyDrive/Project_code/Zea Mays Plant 2/CD-Hit Protein Sequences Zea mays plant-  40% CD-Hit.fasta" \
  --excel2 "/content/drive/MyDrive/Project_code/Zea Mays Plant 2/Zea mays -UB-Sites.xlsx" \
  --pssm1 "/content/drive/MyDrive/Project_code/Triticum aestivum Plant1/PSSM Fetuers for Triticum aestive Plant" \
  --pssm2 "/content/drive/MyDrive/Project_code/Zea Mays Plant 2/PSSM feature for Zea mays Plant" \
  --features pssm \
  --window_size 11 \
  --epochs 10 \
  --batch_size 32 \
  --lr 0.00005 \
  --dropout 0.0 \
  --loss bce \
  --pos_weight 1 \
  --optim amsgrad \
  --sched step \
  --step_size 10 \
  --t_max 10 \
  --gamma 0.1 \
  --device cuda \
  --wandb_project ubiquitination-prediction \
  --wandb_entity ashkan132-fard \
  --wandb_api_key e32e31ab856f60bb3a50f3439a4526ecee094986 \
  --wandb \
  --sampling over \
  --sampling_ratios 30.0 \
  --freeze_pretrained \
  --cv 5 \
  --plots distribution confusion roc pr
# Out:
# ========== ARGUMENTS ==========
# batch_size: 32
# cv: 5
# device: cuda
# dropout: 0.0
# epochs: 10
# excel: /content/drive/MyDrive/Project_code/Triticum aestivum Plant1/Triticum aestive -UB-Sites.xlsx
# excel2: /content/drive/MyDrive/Project_code/Zea Mays Plant 2/Zea mays -UB-Sites.xlsx
# fasta: /content/drive/MyDrive/Project_code/Triticum aestivum Plant1/Protein Sequences Triticum aestive  40% CD-Hit.fasta
# fasta2: /content/drive/MyDrive/Project_code/Zea Mays Plant 2/CD-Hit Protein Sequences Zea mays plant-  40% CD-Hit.fasta
# features: ['pssm']
# freeze_pretrained: True
# gamma: 0.1
# loss: bce
# lr: 5e-05
# model: xgb
# optim: amsgrad
# plots: ['distribution', 'confusion', 'roc', 'pr']
# pos_weight: 1.0
# pssm1: /content/drive/MyDrive/Project_code/Triticum aestivum Plant1/PSSM Fetuers for Triticum aestive Plant
# pssm2: /content/drive/MyDrive/Project_code/Zea Mays Plant 2/PSSM feature for Zea mays Plant
# sampling: ['over']
# sampling_ratios: [30.0]
# sched: step
# ...
